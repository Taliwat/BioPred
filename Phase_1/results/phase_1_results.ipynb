# %%
import pandas as pd
from IPython.display import display

# %%
# Define column names
columns = [
    "Model Name", "Initial MSE", "Initial R2", 
    "Optimized MSE", "Optimized R2", "Use In Stack?", "Notes"
]

# Manually enter results here (you can update as you go)
model_results = [
    {"Model Name": "XGBoost", "Initial MSE": 0.8873, "Initial R2": 0.5588, "Optimized MSE": None, "Optimized R2": None, "Use In Stack?": None, "Notes": None},
    {"Model Name": "RandomForest", "Initial MSE": 0.9162, "Initial R2": 0.5444, "Optimized MSE": None, "Optimized R2": None, "Use In Stack?": None, "Notes": None},
    {"Model Name": "LGBM", "Initial MSE": 0.9114, "Initial R2": 0.5468, "Optimized MSE": None, "Optimized R2": None, "Use In Stack?": None, "Notes": None},
    {"Model Name": "LinearRegression", "Initial MSE": 0.964278, "Initial R2": 0.520526, "Optimized MSE": None, "Optimized R2": None, "Use In Stack?": "No", "Notes": "Linear relationships weak"},
    {"Model Name": "RidgeRegression", "Initial MSE": 0.964271, "Initial R2": 0.520530, "Optimized MSE": 0.963777, "Optimized R2": 0.520776, "Use In Stack?": "No", "Notes": "Marginal improvement"},
    {"Model Name": "LassoRegression", "Initial MSE": 1.096031, "Initial R2": 0.455014, "Optimized MSE": 0.963489, "Optimized R2": 0.520919, "Use In Stack?": "No", "Notes": "Heavy penalization"},
    {"Model Name": "HistGradientBoosting", "Initial MSE": None, "Initial R2": None, "Optimized MSE": None, "Optimized R2": None, "Use In Stack?": None, "Notes": None},
    {"Model Name": "GradientBoosting", "Initial MSE": None, "Initial R2": None, "Optimized MSE": None, "Optimized R2": None, "Use In Stack?": None, "Notes": None},
    {"Model Name": "ExtraTrees", "Initial MSE": None, "Initial R2": None, "Optimized MSE": None, "Optimized R2": None, "Use In Stack?": None, "Notes": None}
]

# Convert to DataFrame
results_df = pd.DataFrame(model_results, columns=columns)

display(results_df)
# Out:
#              Model Name  Initial MSE  Initial R2  Optimized MSE  Optimized R2  \
# 0               XGBoost     0.887300    0.558800            NaN           NaN
# 1          RandomForest     0.916200    0.544400            NaN           NaN
# 2                  LGBM     0.911400    0.546800            NaN           NaN
# 3      LinearRegression     0.964278    0.520526            NaN           NaN
# 4       RidgeRegression     0.964271    0.520530       0.963777      0.520776
# 5       LassoRegression     1.096031    0.455014       0.963489      0.520919
# 6  HistGradientBoosting          NaN         NaN            NaN           NaN
# 7      GradientBoosting          NaN         NaN            NaN           NaN
# 8            ExtraTrees          NaN         NaN            NaN           NaN
#
#   Use In Stack?                      Notes
# 0          None                       None
# 1          None                       None
# 2          None                       None
# ...
